# %% [markdown]
# ### <I style="color: yellow;">!! Note that this notebook was ran in google colab so it may have some <span style="color: red;"> path </span> and <span style="color: red;"> dependencies issues </span> !!</I>

# %% [markdown]
# ## Import dataset from roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="e3IiUsVn3x6gp8lQVOOr")
project = rf.workspace("padel-rbqpp").project("padel-detection-2")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 72.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 94.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to padel-detection-2-1 in yolov8:: 100%|██████████| 3448/3448 [00:00<00:00, 6605.30it/s]

# %% [markdown]
# ## installing ultralytics package for colab

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Base_DIR = "/content/drive/MyDrive/padel_game_model_training"

# %% [markdown]
# ### YOLO training code
# <hr>
#
# #### various model like YOLOv8m, yolov5x were trained and tested. Vary the model as required.

# %%
from ultralytics import YOLO

yolo = YOLO("yolov5x.pt")
results = yolo.train(
  data = "padel-detection-2-1/data.yaml",
  epochs = 60,
  patience = 20,
  batch = 16,
  project = Base_DIR,
  name='finetuned_model_v5x'
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
